# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Autocorrelations and time series decomposition code summary
#
#
#
# ---

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Autocorrelations-and-time-series-decomposition-code-summary" data-toc-modified-id="Autocorrelations-and-time-series-decomposition-code-summary-1">Autocorrelations and time series decomposition code summary</a></span><ul class="toc-item"><li><span><a href="#Example-time-series" data-toc-modified-id="Example-time-series-1.1">Example time series</a></span></li><li><span><a href="#Timeseries-plot" data-toc-modified-id="Timeseries-plot-1.2">Timeseries plot</a></span></li><li><span><a href="#Autocorrelations-and-Partial-Autocorrelations" data-toc-modified-id="Autocorrelations-and-Partial-Autocorrelations-1.3">Autocorrelations and Partial Autocorrelations</a></span></li><li><span><a href="#Seasonal-Decomposition" data-toc-modified-id="Seasonal-Decomposition-1.4">Seasonal Decomposition</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from scipy import stats

plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Example time series

# %%
ts = np.array([ 0.05136508,  0.05786939,  0.13044277,  0.02647674,  0.05248722,
        0.07028412,  0.14695553,  0.04812759,  0.03469104, -0.02226187,
        0.12933155,  0.10363901,  0.11016499,  0.16458528,  0.033267  ,
        0.17236917, -0.01836744,  0.02007639, -0.11210909,  0.02041503,
       -0.09755512,  0.03112965,  0.03977813, -0.08701188, -0.06736843,
       -0.10283528, -0.20098622, -0.09870602, -0.05336285, -0.15262537,
        0.00069851, -0.0278039 , -0.08755499, -0.09683009,  0.06180118,
        0.04517523, -0.03834352, -0.13286284, -0.12209246,  0.13063321,
        0.11911034,  0.05833003, -0.03745672, -0.06922578, -0.08501044,
       -0.14764092, -0.19538914, -0.09853713, -0.06678251, -0.06697418,
       -0.0320541 ,  0.04448269,  0.04851348,  0.07920936,  0.00945947,
       -0.0314999 ,  0.04563163, -0.04800621,  0.14469566,  0.13412217,
        0.08161995,  0.09994485,  0.12712181,  0.0157222 , -0.07075299,
       -0.05650532, -0.01157834,  0.13575643,  0.00914269,  0.07945422,
        0.13949191,  0.03022907,  0.17738829,  0.18848542,  0.29043521,
        0.20961548,  0.17747412,  0.17252334,  0.0950133 ,  0.1497269 ,
        0.07285599,  0.05799956, -0.05112971, -0.01212138, -0.25042948,
       -0.12007097,  0.10770457, -0.10912845, -0.0546013 , -0.03953715,
       -0.10984802, -0.191622  , -0.00263222,  0.00713914, -0.0327242 ,
        0.02016388,  0.22091706,  0.26474175,  0.15604457,  0.1756393 ])

# %% [markdown]
# ## Timeseries plot

# %%
plt.plot(ts);

# %% [markdown]
# ## Autocorrelations and Partial Autocorrelations

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(ts);

# %%
plot_pacf(ts);

# %% [markdown]
# ## Seasonal Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
seasonal_decompose(ts, period=10, extrapolate_trend=True).plot();
