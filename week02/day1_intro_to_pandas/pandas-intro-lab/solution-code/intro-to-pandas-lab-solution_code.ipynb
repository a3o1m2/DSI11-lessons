# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Intro to `pandas` Lab
# ___

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
# ### A. Explore _Mad Men_ Cast Data
#
# ---
#
# #### 1. Load the _Mad Men_ cast data into a `pandas` DataFrame.

# %%
cast_data_csv = '../../../../../resource-datasets/mad_men_actors/mad-men-cast-show-data.csv'

# %%
cast = pd.read_csv(cast_data_csv, encoding='latin-1')

# %% [markdown]
# #### 2. Print the head and tail of the data.

# %%
# A:
cast.head()
# Out:
#           Performer          Show  Show Start Show End Status?  CharEnd  \
# 0       Steven Hill   Law & Order        1990     2010     END     2000
# 1    Kelli Williams  The Practice        1997     2014     END     2003
# 2  LisaGay Hamilton  The Practice        1997     2014     END     2003
# 3  Lara Flynn Boyle  The Practice        1997     2014     END     2003
# 4   Dylan McDermott  The Practice        1997     2014     END     2004
#
#    Years Since  #LEAD  #SUPPORT  #Shows  Score      Score/Y  \
# 0           15      0         0       0   0.00            0
# 1           12      0         1       6   6.25  0.520833333
# 2           12      2         0       2   4.00  0.333333333
# 3           12      0         0       0   0.00            0
# 4           11      2         7       6   9.75  0.886363636
#
#                                    lead_notes  \
# 0                                         NaN
# 1                                         NaN
# ...

# %%
# A:
cast.tail()
# Out:
#            Performer             Show  Show Start Show End Status?  CharEnd  \
# 243     Meghan Wolfe   True Detective        2014  PRESENT    LEFT     2014
# 244       Kevin Dunn   True Detective        2014  PRESENT    LEFT     2014
# 245    Charles Dance  Game of Thrones        2011  PRESENT    LEFT     2015
# 246  Patrick Dempsey   Grey's Anatomy        2005  PRESENT    LEFT     2015
# 247   Ian McElhinney  Game of Thrones        2011  PRESENT    LEFT     2015
#
#      Years Since  #LEAD  #SUPPORT  #Shows  Score  Score/Y lead_notes  \
# 243            1      0         0       0   0.00        0        NaN
# 244            1      0         1       2   2.25     2.25        NaN
# 245            0      0         2       1   1.50  #DIV/0!        NaN
# 246            0      0         0       0   0.00  #DIV/0!        NaN
# 247            0      0         0       0   0.00  #DIV/0!        NaN
#
#                            support_notes                    show_notes
# ...

# %% [markdown]
# #### 3. Print the columns of the data.

# %%
# A:
cast.columns
# Out:
# Index(['Performer', 'Show', 'Show Start', 'Show End', 'Status?', 'CharEnd',
#        'Years Since', '#LEAD', '#SUPPORT', '#Shows', 'Score', 'Score/Y',
#        'lead_notes', 'support_notes', 'show_notes'],
#       dtype='object')

# %% [markdown]
# #### 4. Rename the columns in such a way that no spaces or special symbols are contained.
#
# Hint: Special symbols or spaces are not contained in the uppercase or lowercase letters.

# %%
import string
# the string library has default strings that contain all letters or numbers
uppercase = string.ascii_uppercase
lowercase = string.ascii_lowercase

# %%
# With a for loop

new_columns = []

for name in cast.columns:
    new_name = ''
    for letter in name:
        if letter in uppercase+lowercase:
            new_name += letter
    new_columns.append(new_name)
new_columns
# Out:
# ['Performer',
#  'Show',
#  'ShowStart',
#  'ShowEnd',
#  'Status',
#  'CharEnd',
#  'YearsSince',
#  'LEAD',
#  'SUPPORT',
#  'Shows',
#  'Score',
#  'ScoreY',
#  'leadnotes',
#  'supportnotes',
#  'shownotes']

# %%
# With a list comprehension
new_columns = [ ''.join([l for l in name if l in uppercase+lowercase]) for name in cast.columns ]
new_columns
# Out:
# ['Performer',
#  'Show',
#  'ShowStart',
#  'ShowEnd',
#  'Status',
#  'CharEnd',
#  'YearsSince',
#  'LEAD',
#  'SUPPORT',
#  'Shows',
#  'Score',
#  'ScoreY',
#  'leadnotes',
#  'supportnotes',
#  'shownotes']

# %%
cast.columns = new_columns
cast
# Out:
#                      Performer              Show  ShowStart  ShowEnd Status  \
# 0                  Steven Hill       Law & Order       1990     2010    END
# 1               Kelli Williams      The Practice       1997     2014    END
# 2             LisaGay Hamilton      The Practice       1997     2014    END
# 3             Lara Flynn Boyle      The Practice       1997     2014    END
# 4              Dylan McDermott      The Practice       1997     2014    END
# 5               Camryn Manheim      The Practice       1997     2014    END
# 6                 Steve Harris      The Practice       1997     2014    END
# 7               Marla Sokoloff      The Practice       1997     2014    END
# 8                 Jerry Orbach       Law & Order       1990     2010    END
# 9            Michael Badalucco      The Practice       1997     2014    END
# 10             Michael C. Hall    Six Feet Under       2001     2005    END
# ...

# %% [markdown]
# #### 5. Subset the data where the status of the show is not "END" or "End".

# %%
# A:

cast[(cast['Status'] != 'END') & (cast['Status'] != 'End')]
# Out:
#                Performer                             Show  ShowStart  ShowEnd  \
# 157     Siobhan Finneran                    Downton Abbey       2010  PRESENT
# 162            Eric Dane                   Grey's Anatomy       2005  PRESENT
# 163       David Harewood                         Homeland       2011  PRESENT
# 171          Dan Stevens                    Downton Abbey       2010  PRESENT
# 173     Michelle Fairley                  Game of Thrones       2011  PRESENT
# 177      Morena Baccarin                         Homeland       2011  PRESENT
# 178    Diego Klattenhoff                         Homeland       2011  PRESENT
# 179    Marg Helgenberger  CSI: Crime Scene Investigations       2000  PRESENT
# 200         Jackson Pace                         Homeland       2011  PRESENT
# 201        Morgan Saylor                         Homeland       2011  PRESENT
# 205          Rory McCann                  Game of Thrones       2011  PRESENT
# ...

# %%
# Alternatively
cast[~cast['Status'].isin(['END','End'])]
# Out:
#                Performer                             Show  ShowStart  ShowEnd  \
# 157     Siobhan Finneran                    Downton Abbey       2010  PRESENT
# 162            Eric Dane                   Grey's Anatomy       2005  PRESENT
# 163       David Harewood                         Homeland       2011  PRESENT
# 171          Dan Stevens                    Downton Abbey       2010  PRESENT
# 173     Michelle Fairley                  Game of Thrones       2011  PRESENT
# 177      Morena Baccarin                         Homeland       2011  PRESENT
# 178    Diego Klattenhoff                         Homeland       2011  PRESENT
# 179    Marg Helgenberger  CSI: Crime Scene Investigations       2000  PRESENT
# 200         Jackson Pace                         Homeland       2011  PRESENT
# 201        Morgan Saylor                         Homeland       2011  PRESENT
# 205          Rory McCann                  Game of Thrones       2011  PRESENT
# ...

# %% [markdown]
# #### 6. Print out the performers where the show start is greater than 2005 and the score is greater than 7.

# %%
# A:

cast[(cast['ShowStart']>2005) & (cast['Score']>7)]['Performer']
# Out:
# 95         Scott Porter
# 132      Connie Britton
# 149     Amanda Seyfried
# 157    Siobhan Finneran
# Name: Performer, dtype: object

# %% [markdown]
# #### 7. Select the `performer` and `show` columns for the rows labeled 20 to 25.

# %%
# A:

cast.loc[20:25, ['Performer', 'Show']]
# Out:
#              Performer             Show
# 20    Mary Steenburgen  Joan of Arcadia
# 21  Mathew St. Patrick   Six Feet Under
# 22       Michael Welch  Joan of Arcadia
# 23    Aaron Himelstein  Joan of Arcadia
# 24     Becky Wahlstrom  Joan of Arcadia
# 25     Chris Marquette  Joan of Arcadia

# %%
cast.iloc[20:26, 0:2]
# Out:
#              Performer             Show
# 20    Mary Steenburgen  Joan of Arcadia
# 21  Mathew St. Patrick   Six Feet Under
# 22       Michael Welch  Joan of Arcadia
# 23    Aaron Himelstein  Joan of Arcadia
# 24     Becky Wahlstrom  Joan of Arcadia
# 25     Chris Marquette  Joan of Arcadia

# %% [markdown]
# #### 8. Plot a histogram of score.

# %%
# A: These all create the same chart

cast.Score.hist();
#cast.Score.plot(kind='hist');
#cast.hist(column=['Score']);

# %% [markdown]
# ### B. Explore San Francisco Crime Data
#
# ---
#
# **9. Load the San Francisco crime data set into a DataFrame.**

# %%
crime_csv = '../../../../../resource-datasets/sf_crime/sf_crime_sample.csv'

# %%
# A:

crime = pd.read_csv(crime_csv)
crime
# Out:
#                      Dates            Category  \
# 0      2003-03-23 23:27:00               ARSON
# 1      2006-03-07 06:45:00       LARCENY/THEFT
# 2      2004-03-06 03:00:00        NON-CRIMINAL
# 3      2011-12-03 12:10:00            BURGLARY
# 4      2003-01-10 00:15:00       LARCENY/THEFT
# 5      2012-08-26 03:15:00      SUSPICIOUS OCC
# 6      2008-02-24 22:00:00       VEHICLE THEFT
# 7      2011-03-12 12:14:00             ASSAULT
# 8      2012-12-14 21:45:00             ASSAULT
# 9      2003-09-01 18:00:00               FRAUD
# 10     2007-01-24 17:15:00       DRUG/NARCOTIC
# 11     2009-10-01 00:45:00       DRUG/NARCOTIC
# 12     2009-11-25 22:00:00     SECONDARY CODES
# 13     2003-11-13 09:15:00      OTHER OFFENSES
# 14     2005-11-15 18:36:00      OTHER OFFENSES
# 15     2006-10-19 10:30:00             ASSAULT
# 16     2008-10-13 17:00:00      SUSPICIOUS OCC
# 17     2005-02-23 10:00:00      OTHER OFFENSES
# 18     2014-03-09 20:00:00      MISSING PERSON
# ...

# %% [markdown]
# **10. Look at the dimensions of the crime data.**

# %%
# A:
crime.shape
# Out:
# (25000, 9)

# %% [markdown]
# **11. Look at the data types of the columns and print out the column names.**

# %%
# A:
crime.info()
crime.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 9 columns):
# Dates         25000 non-null object
# Category      25000 non-null object
# Descript      25000 non-null object
# DayOfWeek     25000 non-null object
# PdDistrict    25000 non-null object
# Resolution    25000 non-null object
# Address       25000 non-null object
# X             25000 non-null float64
# Y             25000 non-null float64
# dtypes: float64(2), object(7)
# memory usage: 1.7+ MB
# Dates          object
# Category       object
# Descript       object
# DayOfWeek      object
# PdDistrict     object
# Resolution     object
# Address        object
# X             float64
# Y             float64
# dtype: object

# %%
# A:
crime.columns
# Out:
# Index(['Dates', 'Category', 'Descript', 'DayOfWeek', 'PdDistrict',
#        'Resolution', 'Address', 'X', 'Y'],
#       dtype='object')

# %% [markdown]
# **12. How many distinct districts are there?**
#
# Hint: You can use the command `.unique()` on any pandas series.

# %%
# A:
crime.PdDistrict.unique()
# Out:
# array(['BAYVIEW', 'NORTHERN', 'SOUTHERN', 'TARAVAL', 'MISSION',
#        'INGLESIDE', 'CENTRAL', 'TENDERLOIN', 'RICHMOND', 'PARK'],
#       dtype=object)

# %% [markdown]
# **13. Which day of the week has the most crime?**

# %%
# A:

# Using .describe() will give you top which is the value with the highest count
crime.DayOfWeek.describe()
# Out:
# count      25000
# unique         7
# top       Friday
# freq        3883
# Name: DayOfWeek, dtype: object

# %%
# Iterate through each day of the week

for day in crime.DayOfWeek.unique():
    print(day, crime[crime['DayOfWeek'] == day].shape[0])
# Out:
# Sunday 3313
# Tuesday 3548
# Saturday 3496
# Friday 3883
# Monday 3524
# Wednesday 3657
# Thursday 3579

# %%
# Or use .value_counts()

crime.DayOfWeek.value_counts()
# Out:
# Friday       3883
# Wednesday    3657
# Thursday     3579
# Tuesday      3548
# Monday       3524
# Saturday     3496
# Sunday       3313
# Name: DayOfWeek, dtype: int64

# %%
# Or use .mode()

crime.DayOfWeek.mode()
# Out:
# 0    Friday
# dtype: object

# %% [markdown]
# #### 14. Make a new DataFrame featuring the crime categories and the number of crimes per category.

# %%
# A:

# Create a list with the categories
category_list = crime.Category.value_counts().index
#category_list = crime.Category.unique()

# Create a list with counts per category
category_counts = crime.Category.value_counts().values
#category_counts =[crime[crime['Category'] == cat].shape[0] for cat in categories]

# %%
# Create dataframe from dictionary

crime_category = pd.DataFrame({'category':category_list, 'counts':category_counts})
crime_category
# Out:
#                        category  counts
# 0                 LARCENY/THEFT    4934
# 1                OTHER OFFENSES    3656
# 2                  NON-CRIMINAL    2601
# 3                       ASSAULT    2164
# 4                 DRUG/NARCOTIC    1533
# 5                 VEHICLE THEFT    1506
# 6                     VANDALISM    1280
# 7                      WARRANTS    1239
# 8                      BURGLARY    1023
# 9                SUSPICIOUS OCC     891
# 10               MISSING PERSON     771
# 11                      ROBBERY     630
# 12                        FRAUD     537
# 13              SECONDARY CODES     283
# 14       FORGERY/COUNTERFEITING     281
# 15                  WEAPON LAWS     255
# 16                 PROSTITUTION     223
# 17                     TRESPASS     209
# 18              STOLEN PROPERTY     137
# 19        SEX OFFENSES FORCIBLE     120
# 20           DISORDERLY CONDUCT     105
# 21                  DRUNKENNESS     105
# ...

# %% [markdown]
# **15. Make a DataFrame that includes the districts and crime counts per district. Which district has the most crime?**
#
# *Hint: You can use the `.sort_values()` function to sort your DataFrame by column.*

# %%
# A: 
districts = crime.PdDistrict.unique()

crime_district = pd.DataFrame({'district':crime.PdDistrict.unique(), 'counts':[crime[crime['PdDistrict'] == dist].shape[0] for dist in districts]})
crime_district.sort_values(by='counts', ascending=False)
# Out:
#      district  counts
# 2    SOUTHERN    4413
# 4     MISSION    3416
# 1    NORTHERN    3076
# 0     BAYVIEW    2555
# 6     CENTRAL    2424
# 7  TENDERLOIN    2336
# 5   INGLESIDE    2256
# 3     TARAVAL    1804
# 9        PARK    1438
# 8    RICHMOND    1282

# %%
# Alternatively

crime.PdDistrict.value_counts(sort=True)
# Out:
# SOUTHERN      4413
# MISSION       3416
# NORTHERN      3076
# BAYVIEW       2555
# CENTRAL       2424
# TENDERLOIN    2336
# INGLESIDE     2256
# TARAVAL       1804
# PARK          1438
# RICHMOND      1282
# Name: PdDistrict, dtype: int64
