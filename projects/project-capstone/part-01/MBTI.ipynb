# %% [markdown]
# # Capstone

# %%
import pandas as pd
pd.set_option('display.max_colwidth',1000, 'display.max_columns',1000)

# %%
mbti = pd.read_csv('mbti.csv')

# %% [markdown]
# |||

# %%
mbti.head()
# Out:
#    type  \
# 0  INFJ
# 1  ENTP
# 2  INTP
# 3  INTJ
# 4  ENTJ
#
# ...

# %%
mbti.type.value_counts()
# problem is the severe class imbalance towards Intuitives
# Out:
# INFP    1832
# INFJ    1470
# INTP    1304
# INTJ    1091
# ENTP     685
# ENFP     675
# ISTP     337
# ISFP     271
# ENTJ     231
# ISTJ     205
# ENFJ     190
# ISFJ     166
# ESTP      89
# ESFP      48
# ESFJ      42
# ESTJ      39
# Name: type, dtype: int64

# %%
conc = pd.read_csv('Deep_Effortless_Concentration_Marty-Dugas_Smilek_2017.csv')
conc.shape
# Out:
# (297, 166)

# %%
conc.head()
# Out:
#    bfi1  bfi2  bfi3  bfi4  bfi5  bfi6  bfi7  bfi8  bfi9  bfi10  bfi11  bfi12  \
# 0     5     5     5     1     5     5     5     5     1      5      5      5
# 1     4     4     4     2     4     4     4     3     2      5      5      4
# 2     1     5     5     3     5     1     5     5     1      5      1      5
# 3     4     4     5     1     5     4     5     5     1      5      5      5
# 4     3     2     5     2     5     3     4     4     3      5      4      5
#
#    bfi13  bfi14  bfi15  bfi16  bfi17  bfi18  bfi19  bfi20  bfi21  bfi22  \
# 0      5      1      5      5      5      5      1      5      5      5
# 1      5      2      4      5      4      4      2      5      4      4
# 2      5      2      5      2      1      4      1      5      1      1
# 3      5      2      5      4      4      4      1      5      4      4
# 4      5      4      4      3      4      4      4      5      4      4
#
# ...
