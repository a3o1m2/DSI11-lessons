# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Automated Data Collection: Lincoln Quotes
#
# ---
#
#
# For this lab, you are asked to produce a list of all of Lincoln's quotes available on this page: http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1
#
# Use the `requests` and `BeautifulSoup` libraries in Python.
#
# For a bonus, collect all the quotes from each page available on Successories.

# %%
import requests
from tqdm import tqdm_notebook
from bs4 import BeautifulSoup
import pandas as pd

# %%
a = soup.find('a')
a.find_next_siblings('a')
# Out:
# []

# %%
soup.find('div', attrs={'class':'aboutquote'}).find_next('a').text
# Out:
# 'Lincoln Quotes'

# %%
quote = []
author = []
# category = []

for x in tqdm_notebook(range(0, 13)):
    url = 'http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/{}'.format(x)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    for entry in soup.find_all('div', attrs={'class':'quotebox'}):
        try:
            quote.append(entry.find('div', attrs={'class':'quote'}).text.strip())
        except:
            quote.append(np.nan)
        try:
            author.append(entry.find('span', attrs={'class':'author'}).find_next('a').text.strip())
        except:
            author.append(np.nan)
#         try:
#             category.append(entry.find('a').find_next_siblings('a').text.strip())
#         except:
#             category.append(np.nan)

# %%
# lincoln_quotes = pd.DataFrame({'quote':quote,'author':author,'category':category})
lincoln_quotes = pd.DataFrame({'quote':quote,'author':author})
lincoln_quotes
# Out:
#                                                  quote          author
# 0    "What kills a skunk is the publicity it gives ...  Lincoln Quotes
# 1    "I am for the people of the whole nation doing...  Lincoln Quotes
# 2    "If I had eight hours to chop down a tree, I'd...  Lincoln Quotes
# 3    "Better to remain silent and be thought a fool...  Lincoln Quotes
# 4    "If you would win a man to your cause, first c...  Lincoln Quotes
# 5    "Be not deceived. Revolutions do not go backwa...  Lincoln Quotes
# 6           "I walk slowly, but I never walk backward"  Lincoln Quotes
# 7                   "Whatever you are, be a good one."  Lincoln Quotes
# 8    "Beware of rashness, but with energy, and slee...  Lincoln Quotes
# 9    "You cannot escape the responsibility of tomor...  Lincoln Quotes
# 10   "A lawyer's time and advice are his stock in t...  Lincoln Quotes
# 11   "An old Dutch farmer, who remarked to a compan...  Lincoln Quotes
# ...
